# %%
from easy_sql import mongo

# %%
database = mongo.connect(88,27017,'SourceCode')

# %%
SourceCode = database.list_collection_names()

# %%
increments= [ i for i in SourceCode if 'increment' in i.lower()]

# %%
len(increments)
# Out:
# 75

# %%
table = database['AatBioIncrement']

# %%
data = mongo.select(table)

# %%
def flat(text):
    
    try:
        json_str = json.loads(text)
        if isinstance(json_str,list):
            return pd.
# Out:
#   Input In [97]
#     return pd.
#               ^
# SyntaxError: invalid syntax

# %%
data = data.where(pd.notna(data),None)

# %%
import pandas as pd
pd.DataFrame((j for i in data.price_info if i for j in i))
# Out:
#       catalog    price locale currency currencyLong
# 0        3017      159    XUS        $          USD
# 1        3100      325    XUS        $          USD
# 2       17017      159    XUS        $          USD
# 3        5023      325    XUS        $          USD
# 4        5024     1573    XUS        $          USD
# ...       ...      ...    ...      ...          ...
# 32073     300  1228730     JP        ¥          JPY
# 32074      77      120    XUS        $          USD
# 32075      71      126    XUS        $          USD
# 32076     398    73280     JP        ¥          JPY
# 32077     395    48460     JP        ¥          JPY
#
# [32078 rows x 5 columns]

# %%
data
# .url.to_list()
# Out:
#                        _id                                                url  \
# 0      1560955211577036800  https://www.aatbio.com/products/fluorescein-bi...
# 1      1560955211577036805  https://www.aatbio.com/products/cy5-biotin-con...
# 2      1560955211577036812  https://www.aatbio.com/products/biotin-16-dutp...
# 3      1560955211577036820  https://www.aatbio.com/products/fmoc-asp-bioti...
# 4      1560955211577036837  https://www.aatbio.com/products/readiview-biot...
# ...                    ...                                                ...
# 15498  1568561090182778888  https://www.aatbio.com/products/5-dr6g-5-carbo...
# 15499  1568561090182778886  https://www.aatbio.com/products/sulforhodamine...
# 15500  1568561090182778885  https://www.aatbio.com/products/sulforhodamine...
# 15501  1568561090182778881  https://www.aatbio.com/products/6-roxtra-fluor...
# 15502  1568561090182778880  https://www.aatbio.com/products/6-rox-glycine-...
#
#                                             product_name  \
# 0                      Fluorescein biotin | AAT Bioquest
# 1                    Cy5 biotin conjugate | AAT Bioquest
# 2      Biotin-16-dUTP *1 mM in Tris Buffer (pH 7.5)* ...
# 3               FMOC-Asp(biotinyl-PEG)-OH | AAT Bioquest
# 4             ReadiView™ biotin maleimide | AAT Bioquest
# ...                                                  ...
# 15498  5-dR6G [5-Carboxy-4,7-dichlororhodamine 6G] | ...
# 15499  Sulforhodamine 101 *CAS 60311-02-6* | AAT Bioq...
# 15500     Sulforhodamine 101, sodium salt | AAT Bioquest
# 15501  6-ROXtra™ fluorescence reference solution *25 ...
# 15502  6-ROX glycine *25 uM fluorescence reference so...
#
#                                              description  \
# 0      This bifunctional biotin derivative is used fo...
# 1      This bifunctional Cy5 biotin conjugate demonst...
# 2      The biotin-modified deoxyuridine 5'-triphospha...
# 3      This PEG biotin-labeled amino acid has excelle...
# 4      Biotin/avidin complexes are widely applied for...
# ...                                                  ...
# 15498  5-dR6G (5-Carboxy-4,7-dichlororhodamine 6G) is...
# 15499  Sulforhodamine 101 is a fluorescence reference...
# 15500  Sulforhodamine 101 is a fluorescence reference...
# 15501  6-ROX is predominately used as a reference dye...
# 15502  6-ROX is predominately used as a reference dye...
#
#                                     product_spectrum_src  \
# 0      https://www.aatbio.com/_next/image?url=https%3...
# 1      https://www.aatbio.com/_next/image?url=https%3...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 15498                                               None
# 15499  /_next/image?url=https%3A%2F%2Fimages.aatbio.c...
# 15500  /_next/image?url=https%3A%2F%2Fimages.aatbio.c...
# 15501  /_next/image?url=https%3A%2F%2Fimages.aatbio.c...
# 15502  /_next/image?url=https%3A%2F%2Fimages.aatbio.c...
#
#                                    image_product_gallery  \
# 0      {'product_gallery': 'https://images.aatbio.com...
# 1      {'product_gallery': 'https://images.aatbio.com...
# 2      {'product_gallery': 'https://images.aatbio.com...
# 3      {'product_gallery': 'https://images.aatbio.com...
# 4      {'product_gallery': 'https://images.aatbio.com...
# ...                                                  ...
# 15498  {'product_gallery': 'https://images.aatbio.com...
# 15499  {'product_gallery': 'https://images.aatbio.com...
# 15500  {'product_gallery': 'https://images.aatbio.com...
# 15501  {'product_gallery': 'https://images.aatbio.com...
# 15502  {'product_gallery': 'https://images.aatbio.com...
#
#                                                  generic  \
# 0      [{'title': 'Engineered single-chain dimeric st...
# 1      [{'title': 'A low-cost, high-performance syste...
# 2      [{'title': 'Fluorescent DNA hybridization prob...
# 3      [{'title': 'Profiling the substrate specificit...
# 4      [{'title': 'Evaluation of a new biotin-DOTA co...
# ...                                                  ...
# 15498  [{'title': 'Design and synthesis of fluorescen...
# 15499  [{'title': 'Distinct Transport Properties of H...
# 15500  [{'title': 'Interfacial behavior of sulforhoda...
# 15501  [{'title': 'Four-color DNA sequencing by synth...
# 15502  [{'title': 'Four-color DNA sequencing by synth...
#
#                                                 specific  \
# 0                                                     []
# 1      [{'title': 'Streptavidin cooperative allosteri...
# 2                                                     []
# 3      [{'title': 'Pharmacophore Generation from a Dr...
# 4      [{'title': 'A low-cost, high-performance syste...
# ...                                                  ...
# 15498                                                 []
# 15499                                                 []
# 15500                                                 []
# 15501                                                 []
# 15502                                                 []
#
#                                      Physical properties  \
# 0      {'Molecular weight': '831.01', 'Solvent': 'DMSO'}
# 1      {'Molecular weight': '1353.82', 'Solvent': 'Wa...
# 2      {'Molecular weight': '1013.72', 'Solvent': 'Wa...
# 3                         {'Molecular weight': '783.94'}
# 4      {'Molecular weight': '660.70', 'Solvent': 'DMSO'}
# ...                                                  ...
# 15498  {'Molecular weight': '628.59', 'Solvent': 'DMSO'}
# 15499  {'Molecular weight': '606.71', 'Solvent': 'Wat...
# 15500  {'Molecular weight': '628.69', 'Solvent': 'Wat...
# 15501  {'Molecular weight': '844.80', 'Solvent': 'Wat...
# 15502  {'Molecular weight': '591.65', 'Solvent': 'Wat...
#
#                                      Spectral properties  \
# 0      {'Correction Factor (260 nm)': '0.32', 'Correc...
# 1      {'Correction Factor (260 nm)': '0.02', 'Correc...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 15498                                               None
# 15499  {'Correction Factor (260 nm)': '0.24', 'Correc...
# 15500  {'Correction Factor (260 nm)': '0.24', 'Correc...
# 15501  {'Excitation (nm)': '578', 'Emission (nm)': '5...
# 15502  {'Correction Factor (280 nm)': '0.168', 'Extin...
#
#                             Storage, safety and handling  \
# 0      {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 1      {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 2      {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 3      {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 4      {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# ...                                                  ...
# 15498  {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 15499  {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 15500  {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 15501  {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
# 15502  {'H-phrase': 'H303, H313, H333', 'Hazard symbo...
#
#                                               price_info
# 0      [{'catalog': '3017', 'price': 159, 'locale': '...
# 1      [{'catalog': '3100', 'price': 325, 'locale': '...
# 2      [{'catalog': '17017', 'price': 159, 'locale': ...
# 3      [{'catalog': '5023', 'price': 325, 'locale': '...
# 4      [{'catalog': '3058', 'price': 325, 'locale': '...
# ...                                                  ...
# 15498  [{'catalog': '300', 'price': 1228730, 'locale'...
# 15499  [{'catalog': '77', 'price': 120, 'locale': 'XU...
# 15500  [{'catalog': '71', 'price': 126, 'locale': 'XU...
# 15501  [{'catalog': '398', 'price': 73280, 'locale': ...
# 15502  [{'catalog': '395', 'price': 48460, 'locale': ...
#
# [15503 rows x 12 columns]
